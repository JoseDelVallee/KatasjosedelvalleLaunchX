# %% [markdown]
# ## Kata 2 Capturas

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('C:/Users/José/Documents/Microsoft AZURE/LaunchX/kata2/kata0ima1.png'))

display.display(Image.open('C:/Users/José/Documents/Microsoft AZURE/LaunchX/kata2/kata2ima2.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=589x318 at 0x14C1F5153C0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=354x230 at 0x14C1EEEA830>
