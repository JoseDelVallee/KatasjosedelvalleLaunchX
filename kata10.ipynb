# %% [markdown]
# ## Kata 10 Capturas

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('C:/Users/José/Documents/Microsoft AZURE/LaunchX/kata10/kata10ima1.png'))

display.display(Image.open('C:/Users/José/Documents/Microsoft AZURE/LaunchX/kata10/kata10ima2.png'))

display.display(Image.open('C:/Users/José/Documents/Microsoft AZURE/LaunchX/kata10/kata10ima3.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=589x375 at 0x1F92CD14B80>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=589x393 at 0x1F92C6C95A0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=589x378 at 0x1F92C6C9570>
